# %%
from pandas import *
from numpy import *
from seaborn import *
import matplotlib.pyplot as pl
zxc=read_csv("/kaggle/input/fifa-player-stats-database/FIFA23_official_data.csv")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
asd=read_csv("/kaggle/input/fifa-player-stats-database/FIFA23_official_data.csv")
col=['Name','Age','Nationality','Value','Overall','Potential']
asd=asd[col]
asd.head(17)
# Out:
#                    Name  Age Nationality    Value  Overall  Potential
# 0           L. Goretzka   27     Germany     €91M       87         88
# 1       Bruno Fernandes   27    Portugal   €78.5M       86         87
# 2              M. Acuña   30   Argentina   €46.5M       85         85
# 3          K. De Bruyne   31     Belgium  €107.5M       91         91
# 4            N. Barella   25       Italy   €89.5M       86         89
# 5            J. Kimmich   27     Germany  €105.5M       89         90
# 6              D. Alaba   30     Austria   €55.5M       86         86
# 7           22 Paulinho   32      Brazil   €28.5M       83         83
# 8                E. Can   28     Germany   €30.5M       82         82
# 9          João Cancelo   28    Portugal   €82.5M       88         88
# 10        L. Pellegrini   26       Italy     €55M       84         87
# 11            L. Modrić   36     Croatia     €29M       88         88
# ...

# %%
zxc.shape
# Out:
# (17660, 29)

# %%
print(asd.index)
# Out:
# RangeIndex(start=0, stop=17660, step=1)

# %%
print(asd.columns)
# Out:
# Index(['Name', 'Age', 'Nationality', 'Value', 'Overall', 'Potential'], dtype='object')

# %%
zxc.ndim
# Out:
# 2

# %%
asd.tail(17)
# Out:
#                   Name  Age     Nationality  Value  Overall  Potential
# 17643  21 J. Langballe   16         Denmark  €100K       50         67
# 17644     22 N. Sorras   23       Australia   €80K       50         57
# 17645      22 J. Kenny   17       Australia   €80K       49         60
# 17646          R. Badu   20         Belgium  €150K       52         61
# 17647  21 P. Blakenall   30         England   €30K       50         50
# 17648   21 K. Bielikow   19          Poland  €120K       51         66
# 17649        Ji Jiabao   19        China PR  €100K       50         65
# 17650     22 G. Leijon   19          Sweden  €150K       52         62
# 17651           Wu Fei   32        China PR   €30K       51         51
# 17652      22 E. Grosz   18         Romania  €180K       52         70
# 17653      22 S. Booth   20         England  €110K       51         60
# 17654     22 L. Grimpe   17         Germany  €210K       54         68
# ...

# %%
zxc.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   17660.000000  17660.000000  17660.000000  17660.000000  17660.000000
# mean   246319.424462     23.127746     63.369592     70.981200   1537.915855
# std     31487.892861      4.639821      8.036268      6.529836    285.893809
# min        16.000000     15.000000     43.000000     42.000000    749.000000
# 25%    240732.500000     20.000000     58.000000     67.000000   1387.000000
# 50%    257041.000000     22.000000     63.000000     71.000000   1548.000000
# 75%    263027.500000     26.000000     69.000000     75.000000   1727.000000
# max    271340.000000     54.000000     91.000000     95.000000   2312.000000
#
#        International Reputation     Weak Foot   Skill Moves    Kit Number
# count              17660.000000  17660.000000  17660.000000  17625.000000
# mean                   1.106285      2.900340      2.297169     25.037957
# ...

# %%
asd.isnull()
# Out:
#         Name    Age  Nationality  Value  Overall  Potential
# 0      False  False        False  False    False      False
# 1      False  False        False  False    False      False
# 2      False  False        False  False    False      False
# 3      False  False        False  False    False      False
# 4      False  False        False  False    False      False
# ...      ...    ...          ...    ...      ...        ...
# 17655  False  False        False  False    False      False
# 17656  False  False        False  False    False      False
# 17657  False  False        False  False    False      False
# 17658  False  False        False  False    False      False
# 17659  False  False        False  False    False      False
#
# [17660 rows x 6 columns]

# %%
zxc.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          211
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                  0
# International Reputation        0
# Weak Foot                       0
# Skill Moves                     0
# Work Rate                       0
# Body Type                      38
# Real Face                      38
# Position                       35
# Joined                       1098
# Loaned From                 16966
# Contract Valid Until          361
# Height                          0
# Weight                          0
# Release Clause               1151
# ...

# %%
zxc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17660 entries, 0 to 17659
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17660 non-null  int64
#  1   Name                      17660 non-null  object
#  2   Age                       17660 non-null  int64
#  3   Photo                     17660 non-null  object
#  4   Nationality               17660 non-null  object
#  5   Flag                      17660 non-null  object
#  6   Overall                   17660 non-null  int64
#  7   Potential                 17660 non-null  int64
#  8   Club                      17449 non-null  object
#  9   Club Logo                 17660 non-null  object
#  10  Value                     17660 non-null  object
#  11  Wage                      17660 non-null  object
#  12  Special                   17660 non-null  int64
# ...

# %%
vbnv={'Name':['Cristiano Ronaldo','L. Messi'],'Age':['37','35'],'Nationality':['Portugal','Argentina'],'Overall':['90','91'],'Potential':['90','91']}
uoo = DataFrame(vbnv)
uoo
# Out:
#                 Name Age Nationality Overall Potential
# 0  Cristiano Ronaldo  37    Portugal      90        90
# 1           L. Messi  35   Argentina      91        91

# %%
asd.loc[asd.Age>30][0:7]
# Out:
#             Name  Age Nationality    Value  Overall  Potential
# 3   K. De Bruyne   31     Belgium  €107.5M       91         91
# 7    22 Paulinho   32      Brazil   €28.5M       83         83
# 11     L. Modrić   36     Croatia     €29M       88         88
# 16    I. Perišić   33     Croatia   €26.5M       84         84
# 18  A. Griezmann   31      France   €30.5M       83         83
# 19   J. Cuadrado   34    Colombia   €13.5M       83         83
# 22     L. Suárez   35     Uruguay     €18M       84         84

# %%
asd.loc[asd.Potential>=90][0:13]
# Out:
#                    Name  Age  Nationality    Value  Overall  Potential
# 3          K. De Bruyne   31      Belgium  €107.5M       91         91
# 5            J. Kimmich   27      Germany  €105.5M       89         90
# 17           F. de Jong   25  Netherlands  €116.5M       87         92
# 21  T. Alexander-Arnold   23      England  €100.5M       87         90
# 25             M. Salah   30        Egypt  €115.5M       90         90
# 26            S. Tonali   22        Italy   €62.5M       84         90
# 41       R. Lewandowski   33       Poland     €84M       91         91
# 46         T. Hernández   24       France     €76M       85         90
# 56             L. Messi   35    Argentina     €54M       91         91
# 59          F. Valverde   23      Uruguay     €66M       84         90
# 70        J. Bellingham   19      England   €81.5M       84         91
# 75            K. Mbappé   23       France  €190.5M       91         95
# ...

# %%
asd.sort_values(['Overall'],ascending=True)[0:23]
# Out:
#                     Name  Age          Nationality  Value  Overall  Potential
# 17618       07 I. Paskov   33             Bulgaria     €0       43         42
# 16215     22 J. Looschen   24              Germany   €60K       44         47
# 14634   22 Zhang Wenxuan   16             China PR  €110K       44         59
# 16042  20 Kim Yeong Geun   22       Korea Republic   €40K       44         49
# 15513    22 Jung Ho Yeon   20       Korea Republic  €100K       45         53
# 14353      22 Chen Zeshi   16             China PR  €100K       45         55
# 14624     22 Zhang Yujun   19             China PR  €100K       46         56
# 14966            A. Khan   21                India  €120K       46         58
# 15027         22 Xie Jie   20             China PR   €70K       46         52
# 15505           B. Singh   22                India  €110K       46         54
# 13399          N. Saliba   18               Canada  €120K       46         63
# ...

# %%
data =Series(asd['Potential'])
data.plot(kind='box')
# Out:
# <Axes: >

# %%
data2=Series(asd['Age'])[0:156]
data2.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data7=Series(asd['Overall'])[0:50]
data7.plot(kind='line')
# Out:
# <Axes: >
